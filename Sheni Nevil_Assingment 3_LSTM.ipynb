# %%
# Importing the required libraries and files for the code
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from keras.layers import SimpleRNN, Dense, Dropout, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Loading the train and test dataset
data_train = pd.read_csv("Google_Stock_Price_Train.csv")
data_test = pd.read_csv("Google_Stock_Price_Test.csv")
# Displaying first 3 rows of train and test data
print(f"The first 3 rows of Train data :\n {data_train.head(3)}\n")
print(f"The first 3 rows of Test data :\n {data_test.head(3)}\n\n")

# Splitting train data as train and validation sets (70% train & 30% validation)
length_data = len(data_train)
split_ratio = 0.7
length_train = round(length_data*split_ratio)  
length_validation = length_data-length_train
print("Length of total train data :", length_data)
print("Splitted train data length :", length_train)
print("Splitted validation data length :", length_validation)

train_data = data_train[:length_train]
# Converting to date-time object
train_data['Date'] = pd.to_datetime(train_data['Date'])
train_data.head(3)

validation_data = data_train[length_train:]
# Converting to date-time object
validation_data['Date'] = pd.to_datetime(validation_data['Date'])
validation_data.head(3)

# Creating the test dataset
test_data = data_test
# Converting to date-time object
test_data['Date'] = pd.to_datetime(test_data['Date'])  
test_data.head(3)

# Creating train dataset from the splitted train 
dataset_train = train_data.Close.values
# Changing 1D to 2D array (changing shape from (1692,) to (1692,1))
dataset_train = np.reshape(dataset_train,(-1,1))
dataset_train.shape

# Creating test dataset from the splitted train
dataset_test = test_data.Close.values
# Changing 1D to 2D array
dataset_test = np.reshape(dataset_test,(-1,1))
dataset_test.shape

# Creating validation dataset from Train split
dataset_val = validation_data.Close.values
# Changing 1D to 2D array (changing shape from (1692,) to (1692,1))
dataset_val = np.reshape(dataset_val,(-1,1))
dataset_val.shape

# Replacing column type
def preprocess_column(column):
    if column.dtype == 'object':
        return column.astype(str).str.replace(',', '').astype(float)
    return column
# Ensuring preprocessing is applied to the original pandas DataFrame
data_train['Close'] = preprocess_column(data_train['Close'])
data_test['Close'] = preprocess_column(data_test['Close'])
validation_data['Close'] = preprocess_column(validation_data['Close'])
# Extracting numpy arrays
dataset_train = data_train['Close'].values.reshape(-1,1)
dataset_test = data_test['Close'].values.reshape(-1,1)
dataset_val = validation_data['Close'].values.reshape(-1,1)

# Feature scaling
scaler = MinMaxScaler(feature_range = (0,1))
# scaling dataset
dataset_train_scaled = scaler.fit_transform(dataset_train)
dataset_val_scaled = scaler.fit_transform(dataset_val)
dataset_test_scaled = scaler.fit_transform(dataset_test)
plt.subplots(figsize = (5,3))
plt.plot(dataset_train_scaled)
plt.xlabel("Days")
plt.ylabel("Close Price")
plt.show()

# Creating X_train and y_train from train dataset
X_train = []
y_train = []
time_step = 2
for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0])
    y_train.append(dataset_train_scaled[i,0])
# Converting list to array
X_train, y_train = np.array(X_train), np.array(y_train)
print("X_train before reshape :",X_train.shape)
print("y_train before reshape :",y_train.shape)
# Reshaping the datasets
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))
print("X_train after reshape :",X_train.shape)
print("y_train after reshape :",y_train.shape)

# Creating X_val and y_val from validation data
X_val = []
y_val = []
time_step = 2
for i in range(time_step, length_validation):
    X_val.append(dataset_val_scaled[i-time_step:i,0])
    y_val.append(dataset_val_scaled[i,0])
# Convert list to array
X_val, y_val = np.array(X_val), np.array(y_val)
print("X_val before reshape :",X_val.shape)
print("y_val before reshape :",y_val.shape)
# Reshaping the datasets
X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1],1))
y_val = np.reshape(y_val, (y_val.shape[0],1))
print("X_val after reshape :",X_val.shape)
print("y_val after reshape :",y_val.shape)

# Creating X_test and y_test from the test data
X_test = []
y_test = []
time_step = 2
length_test = len(data_test)
for i in range(time_step, length_test):
    X_test.append(dataset_test_scaled[i-time_step:i,0])
    y_test.append(dataset_test_scaled[i,0])
# Convert list to array
X_test, y_test = np.array(X_test), np.array(y_test)
print("X_test before reshape :",X_test.shape)
print("y_test before reshape :",y_test.shape)
# Reshaping the datasets
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
y_test = np.reshape(y_test, (y_test.shape[0],1))
print("X_test after reshape :",X_test.shape)
print("y_test after reshape :",y_test.shape)

model_lstm = Sequential()
# Adding a 64 lstm neuron block
model_lstm.add(LSTM(64, return_sequences=False, input_shape = (X_train.shape[1],1)))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["accuracy"])
history2 = model_lstm.fit(X_train, y_train, epochs = 100, batch_size = 10)

def evaluate_model_performance(y_true, y_pred):
    # Calculating Mean Squared Error (MSE)
    mse = mean_squared_error(y_true, y_pred)
    print(f"Mean Squared Error(MSE) : {mse}")
    # Calculating Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_true, y_pred)
    print(f"Mean Absolute Error (MAE) : {mae}")
    # Calculating Root Mean Squared Error (RMSE)
    rmse = np.sqrt(mse)
    print(f"Root Mean Squared Error (RMSE) : {rmse}")
    # Defining tolerance level
    tolerance = 0.01
    # Calculating percentage difference between actual and predicted values
    percentage_difference = np.abs((y_pred-y_true)/y_true)
    # Checking if predictions are within tolerance
    within_tolerance = percentage_difference < tolerance
    # Calculating accuracy as a percentage of predictions within the tolerance
    accuracy = np.mean(within_tolerance) * 100
    print(f"Accuracy (within {tolerance * 100}% tolerance) : {accuracy:.2f}%")

def evaluate_predictions(model, X_data, y_data, scaler, data_type="Train"):
    # Predicting the data
    predictions = model.predict(X_data)
    # Inverse transforming predicted and actual values
    predictions = scaler.inverse_transform(predictions)
     # Ensuring actual values are also inverse transformed
    y_data = scaler.inverse_transform(y_data)   
    # Plotting predictions vs actual values
    plt.subplots(figsize=(5,3))
    plt.plot(predictions, label=f"y_pred_of_{data_type.lower()}", color="orange")
    plt.plot(y_data, label=f"y_{data_type.lower()}", color="g")
    plt.xlabel("Days")
    plt.ylabel("Open price")
    plt.title(f"LSTM Model: Predicting -> input X_{data_type.lower()} vs y_{data_type.lower()}")
    plt.legend()
    plt.show()
    # Evaluating model performance
    evaluate_model_performance(y_data, predictions)
plt.figure(figsize = (5,3))
plt.plot(history2.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("LSTM Model : Accuracy vs Epoch")
plt.show()

evaluate_predictions(model_lstm, X_train, y_train, scaler, data_type="Train")
evaluate_predictions(model_lstm, X_val, y_val, scaler, data_type="Validation")
evaluate_predictions(model_lstm, X_test, y_test, scaler, data_type="Test")
# Out:
# The first 3 rows of Train data :
#         Date    Open    High     Low   Close     Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59  7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45  5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21  6,590,300
#
# The first 3 rows of Test data :
#         Date    Open    High     Low   Close     Volume
# 0  1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1  1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2  1/5/2017  786.08  794.48  785.02  794.02  1,335,200
#
#
# Length of total train data : 1258
# Splitted train data length : 881
# Splitted validation data length : 377
# C:\Users\Sheni Nevil\AppData\Local\Temp\ipykernel_25864\1638946445.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Date'] = pd.to_datetime(train_data['Date'])
# C:\Users\Sheni Nevil\AppData\Local\Temp\ipykernel_25864\1638946445.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data['Date'] = pd.to_datetime(validation_data['Date'])
# C:\Users\Sheni Nevil\AppData\Local\Temp\ipykernel_25864\1638946445.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data['Close'] = preprocess_column(validation_data['Close'])
# X_train before reshape : (879, 2)
# y_train before reshape : (879,)
# X_train after reshape : (879, 2, 1)
# y_train after reshape : (879, 1)
# X_val before reshape : (375, 2)
# y_val before reshape : (375,)
# X_val after reshape : (375, 2, 1)
# y_val after reshape : (375, 1)
# X_test before reshape : (18, 2)
# y_test before reshape : (18,)
# X_test after reshape : (18, 2, 1)
# y_test after reshape : (18, 1)
# C:\Users\Sheni Nevil\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 4.1247e-04 - loss: 0.1193
# Epoch 2/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0028 - loss: 0.0090
# Epoch 3/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0027 - loss: 0.0011
# Epoch 4/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 8.1967e-04 - loss: 0.0026
# Epoch 5/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0012 - loss: 0.0033
# Epoch 6/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 4.3299e-04 - loss: 0.0014
# Epoch 7/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 8.2142e-04 - loss: 5.9363e-04
# Epoch 8/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0018 - loss: 0.0014
# Epoch 9/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0014 - loss: 0.0012
# Epoch 10/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0031 - loss: 0.0018
# Epoch 11/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 7.4323e-04 - loss: 8.6542e-04
# Epoch 12/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0030 - loss: 0.0029
# Epoch 13/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0024 - loss: 6.1090e-04
# Epoch 14/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0061 - loss: 0.0015
# Epoch 15/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0025 - loss: 7.7248e-04
# Epoch 16/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0048 - loss: 0.0025
# Epoch 17/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0013 - loss: 0.0046
# Epoch 18/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0036 - loss: 0.0018
# Epoch 19/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0034 - loss: 7.0828e-04
# Epoch 20/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0012 - loss: 0.0013
# Epoch 21/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 7.5731e-04 - loss: 8.9820e-04
# Epoch 22/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0040 - loss: 0.0022
# Epoch 23/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0030 - loss: 4.6726e-04
# Epoch 24/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0026 - loss: 9.5366e-04
# Epoch 25/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0030 - loss: 6.3877e-04
# Epoch 26/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0012 - loss: 0.0018
# Epoch 27/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0093 - loss: 5.2453e-04
# Epoch 28/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0012 - loss: 0.0014
# Epoch 29/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0021 - loss: 0.0014
# Epoch 30/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0023 - loss: 0.0024
# Epoch 31/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0048 - loss: 0.0026
# Epoch 32/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0023 - loss: 0.0028
# Epoch 33/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0026 - loss: 0.0030
# Epoch 34/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0018 - loss: 7.6785e-04
# Epoch 35/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0040 - loss: 0.0010
# Epoch 36/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0021 - loss: 0.0019
# Epoch 37/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0014 - loss: 0.0016
# Epoch 38/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 6.9353e-04 - loss: 0.0017
# Epoch 39/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0014 - loss: 0.0016
# Epoch 40/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0021 - loss: 9.0678e-04
# Epoch 41/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0013 - loss: 6.4477e-04
# Epoch 42/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0034 - loss: 0.0011
# Epoch 43/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0021 - loss: 2.9288e-04
# Epoch 44/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0012 - loss: 0.0014
# Epoch 45/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0028 - loss: 0.0020
# Epoch 46/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 3.0677e-04 - loss: 0.0014
# Epoch 47/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0038 - loss: 7.1631e-04
# Epoch 48/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0027 - loss: 6.8222e-04
# Epoch 49/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0011 - loss: 0.0018
# Epoch 50/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 2.1500e-04 - loss: 0.0010
# Epoch 51/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0021 - loss: 7.3161e-04
# Epoch 52/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0011 - loss: 0.0025
# Epoch 53/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0016 - loss: 5.6092e-04
# Epoch 54/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0027 - loss: 7.1285e-04
# Epoch 55/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0023 - loss: 0.0014
# Epoch 56/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0023 - loss: 4.9708e-04
# Epoch 57/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0021 - loss: 8.6772e-04
# Epoch 58/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0011 - loss: 0.0024
# Epoch 59/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0016 - loss: 0.0016
# Epoch 60/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0014 - loss: 3.2666e-04
# Epoch 61/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0018 - loss: 9.2200e-04
# Epoch 62/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0026 - loss: 0.0012
# Epoch 63/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0036 - loss: 8.1288e-04
# Epoch 64/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 5.3184e-04 - loss: 8.0721e-04
# Epoch 65/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 8.5198e-04 - loss: 5.8715e-04
# Epoch 66/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0016 - loss: 0.0033
# Epoch 67/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 6.0508e-04 - loss: 0.0012
# Epoch 68/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0022 - loss: 4.2332e-04
# Epoch 69/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 7.9067e-04 - loss: 4.8978e-04
# Epoch 70/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0074 - loss: 0.0026
# Epoch 71/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0027 - loss: 5.1385e-04
# Epoch 72/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0018 - loss: 3.6093e-04
# Epoch 73/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0026 - loss: 0.0018
# Epoch 74/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 5.7241e-04 - loss: 2.5047e-04
# Epoch 75/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 4.3392e-04 - loss: 3.6215e-04
# Epoch 76/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0047 - loss: 5.0934e-04
# Epoch 77/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0043 - loss: 0.0024
# Epoch 78/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0043 - loss: 3.5067e-04
# Epoch 79/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0021 - loss: 5.9869e-04
# Epoch 80/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0014 - loss: 8.5356e-04
# Epoch 81/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 4.0249e-04 - loss: 0.0013
# Epoch 82/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0014 - loss: 4.8930e-04
# Epoch 83/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0042 - loss: 5.6900e-04
# Epoch 84/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 4.4210e-04 - loss: 5.2740e-04
# Epoch 85/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0018 - loss: 0.0023
# Epoch 86/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0021 - loss: 6.5245e-04
# Epoch 87/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0027 - loss: 2.8115e-04
# Epoch 88/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0066 - loss: 7.3732e-04
# Epoch 89/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0018 - loss: 6.0711e-04
# Epoch 90/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0020 - loss: 5.1891e-04
# Epoch 91/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0019 - loss: 9.1520e-04
# Epoch 92/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 5.5056e-04 - loss: 6.6030e-04
# Epoch 93/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 3.7173e-04 - loss: 3.5471e-04
# Epoch 94/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0035 - loss: 5.8336e-04
# Epoch 95/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0026 - loss: 0.0012
# Epoch 96/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 9.6906e-04 - loss: 0.0015
# Epoch 97/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0033 - loss: 0.0015
# Epoch 98/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0078 - loss: 0.0010
# Epoch 99/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 8.1401e-04 - loss: 4.6215e-04
# Epoch 100/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0036 - loss: 0.0012
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Mean Squared Error(MSE) : 2.2555560397300454
# Mean Absolute Error (MAE) : 0.5425871603687987
# Root Mean Squared Error (RMSE) : 1.5018508713351153
# Accuracy (within 1.0% tolerance) : 99.89%
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error(MSE) : 3.6703359519923153
# Mean Absolute Error (MAE) : 1.2744058952442665
# Root Mean Squared Error (RMSE) : 1.915812086816532
# Accuracy (within 1.0% tolerance) : 99.47%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Mean Squared Error(MSE) : 69.38626716291209
# Mean Absolute Error (MAE) : 6.263082546657984
# Root Mean Squared Error (RMSE) : 8.329841965062247
# Accuracy (within 1.0% tolerance) : 72.22%
